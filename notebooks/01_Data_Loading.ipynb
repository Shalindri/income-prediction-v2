# %%
import pandas as pdimport numpy as npimport matplotlib.pyplot as pltimport seaborn as sns

# %%
# Load datadf = pd.read_csv("../data/adult.csv")print(f"✓ Data loaded: {df.shape}")print(f"✓ Columns: {df.columns.tolist()}")

# %%
# Data infoprint(df.info())print("\n" + "="*50)print(df.describe())

# %%
# Check target distributionprint("Target Distribution:")print(df['income'].value_counts())plt.figure(figsize=(8, 5))df['income'].value_counts().plot(kind='bar')plt.title("Income Distribution")plt.ylabel("Count")plt.show()

# %%
# Check missing valuesprint("Missing Values:")print(df.isnull().sum())

# %%
# Save for next notebookdf.to_csv("/tmp/adult_raw.csv", index=False)print("✓ Data saved for next notebook")

# %% [markdown]
# ✅ Data Loaded!Next: Run notebook `02_Feature_Engineering.py`
