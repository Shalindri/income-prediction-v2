# %%
# Install packages
# %pip install scikit-learn pandas numpy matplotlib seaborn imbalanced-learn shap mlflow --quiet
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: /Users/shalindri/Documents/MSc/ML/CW/income-prediction/venv/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Install packages
#       2 get_ipython().run_line_magic('pip', 'install scikit-learn pandas numpy matplotlib seaborn imbalanced-learn shap mlflow --quiet')
# ----> 3 dbutils.library.restartPython()
#
# NameError: name 'dbutils' is not defined

# %%
import mlflow 
import pandas as pd
import numpy as np
print("✓ Libraries imported")
# Out:
# ✓ Libraries imported

# %%
# Configuration
PROJECT_CONFIG = {    "project_name": "adult_income_prediction",    "author": "shalindri20@gmail.com",    "mlflow_experiment": "/Users/shalindri20@gmail.com/Adult_Income_MLflow_Production",    "data_path": "../data/adult.csv",    "random_state": 42,    "test_size": 0.2}
# Set MLflow experiment
mlflow.set_experiment(PROJECT_CONFIG["mlflow_experiment"])
experiment = mlflow.get_experiment_by_name(PROJECT_CONFIG["mlflow_experiment"])
print(f"✓ MLflow Experiment: {experiment.name}")
print(f"✓ Experiment ID: {experiment.experiment_id}")
# Out:
# /Users/shalindri/Documents/MSc/ML/CW/income-prediction/venv/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/utils.py:140: FutureWarning: Filesystem tracking backend (e.g., './mlruns') is deprecated. Please switch to a database backend (e.g., 'sqlite:///mlflow.db'). For feedback, see: https://github.com/mlflow/mlflow/issues/18534
#   return FileStore(store_uri, store_uri)
# 2025/11/16 08:25:44 INFO mlflow.tracking.fluent: Experiment with name '/Users/shalindri20@gmail.com/Adult_Income_MLflow_Production' does not exist. Creating a new experiment.
# ✓ MLflow Experiment: /Users/shalindri20@gmail.com/Adult_Income_MLflow_Production
# ✓ Experiment ID: 960396990422304723

# %% [markdown]
# ✅ Setup Complete!Next: Run notebook `01_Data_Loading.py`
